# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import re
import joblib
import string

# %%
fake = pd.read_csv('Fake.csv')
true = pd.read_csv('True.csv')

fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  class
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
# adding a new column called "class" to each DataFrame
fake['class'] = 0
true['class'] = 1

# %%
# Combine both datasets
data = pd.concat([fake, true], axis=0)

# %%
data.sample(10)
# Out:
#                                                    title  \
# 2312    Trump Just Got Some Really, REALLY Bad News A...
# 6464    Cruz Campaign Blames Rubio For Loss: A Cruz/R...
# 3804   Trump did not ask former FBI Director Comey to...
# 14121  "The people have spoken," Zimbabwe's Mnangagwa...
# 22990             The Changing Face of Mainstream Media?
# 20280  BIKERS FOR TRUMP: “Not Going To Put Up With” V...
# 2852    The Numbers Are In: Trump Is The Most Hated N...
# 18452  Pakistani activist targeted by blast vows to m...
# 8072       Kansas argues against boost in school funding
# 4583    Trump Is Pretending He Doesn’t Want To Sue Th...
#
#                                                     text       subject  \
# 2312   Donald Trump has been playing games with his t...          News
# 6464   Now that the side-show is essentially over and...          News
# 3804   WASHINGTON (Reuters) - U.S. President Donald T...  politicsNews
# 14121  HARARE (Reuters) - Zimbabwe s former vice pres...     worldnews
# 22990  21st Century Wire says One of the biggest tren...   Middle-east
# 20280   Veterans are the backbone of the biker commun...     left-news
# 2852   It s been less than a week since Donald Trump ...          News
# 18452  DERA ISMAIL KHAN, Pakistan (Reuters) - A Pakis...     worldnews
# 8072   (Reuters) - Kansas sought on Wednesday to avoi...  politicsNews
# 4583   Donald Trump reverted to his usual grouchy, un...          News
#
#                       date  class
# 2312         March 3, 2017      0
# 6464           May 9, 2016      0
# 3804         May 12, 2017       1
# 14121   November 22, 2017       1
# 22990    February 17, 2017      0
# 20280         Jul 14, 2016      0
# 2852      January 25, 2017      0
# 18452     October 3, 2017       1
# 8072   September 21, 2016       1
# 4583    September 17, 2016      0

# %%
print(data.columns)  # See all available columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
columns_to_drop = ["title", "subject", "date"]
existing_cols = [col for col in columns_to_drop if col in data.columns]
data = data.drop(existing_cols, axis=1)

# %%
print(data.columns)
# Out:
# Index(['text', 'class'], dtype='object')

# %%
data.sample(5)
# Out:
#                                                     text  class
# 17018  SOCHI, Russia (Reuters) - Russian President Vl...      1
# 21696  Megyn Kelly interviews The Blaze s Dana Loesch...      0
# 5538   GOP Senator Ben Sasse of Nebraska has been one...      0
# 5206   WASHINGTON (Reuters) - A bipartisan group of U...      1
# 14668  ANKARA (Reuters) - Turkey, Russia and Iran wil...      1

# %%
data.reset_index(inplace=True)

# %%
data.drop(['index'], axis=1, inplace=True)

# %%
data.sample(5)
# Out:
#                                                     text  class
# 18978                                                         0
# 30839  (Reuters) - Former Los Angeles Mayor and forme...      1
# 6584   Almost a decade after targeting the black comm...      0
# 36892  WASHINGTON (Reuters) - The U.S. State Departme...      1
# 25090  WASHINGTON (Reuters) - U.S. Health Secretary T...      1

# %%
def clean_text(text):
    text = re.sub(r'http\S+', '', text)  # Remove URLs
    text = re.sub(r'[^A-Za-z\s]', '', text)  # Remove punctuation/numbers
    text = text.lower()
    return text

# %%
data["text"] = data["text"].apply(clean_text)

# %%
print(data["text"].head())        # view cleaned text
print(data["text"].isnull().sum())  # check if any rows became null
# Out:
# 0    donald trump just couldn t wish all americans ...
# 1    house intelligence committee chairman devin nu...
# 2    on friday it was revealed that former milwauke...
# 3    on christmas day donald trump announced that h...
# 4    pope francis used his annual christmas day mes...
# Name: text, dtype: object
# 0

# %%
data.sample(5)
# Out:
#                                                     text  class
# 35956  gaza reuters  two palestinian islamic jihad mi...      1
# 43452  wellington reuters  support for new zealand s ...      1
# 19449  politico has terminated its contract with maga...      0
# 24368  reuters  goldman sachs group inc gsn chief exe...      1
# 32948  austin texas reuters  a texasbased lgbt advoca...      1

# %%
x = data["text"]
y = data["class"]
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
print(xtrain.head())     # Shows the first 5 training text samples
print(ytrain.head())     # Shows the corresponding labels (0 = fake, 1 = real)
# Out:
# 34830    seoul reuters  south korea predicted on tuesda...
# 6018     beebe arkansas mayor mike robertson loves jesu...
# 42549    new york reuters  eighty percent of the power ...
# 8670     when the black lives matter movement started g...
# 27243    washington reuters  the trump administrations ...
# Name: text, dtype: object
# 34830    1
# 6018     0
# 42549    1
# 8670     0
# 27243    1
# Name: class, dtype: int64

# %%
# Cell 1: Vectorization using TF-IDF
vectorizer = TfidfVectorizer()
xv_train = vectorizer.fit_transform(xtrain)
xv_test = vectorizer.transform(xtest)

# %%
lr = LogisticRegression()
lr.fit(xv_train, ytrain)
# Out:
# LogisticRegression()

# %%
prediction = lr.predict(xv_test)
lr.score(xv_test, ytest)
# Out:
# 0.9898440979955456

# %%
from sklearn.metrics import classification_report

print(classification_report(ytest, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5895
#            1       0.99      0.99      0.99      5330
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
import joblib

joblib.dump(vectorizer, "vectorizer.joblib")
joblib.dump(lr, "lr_model.joblib")
# Out:
# ['lr_model.joblib']
